# %%
a=43
b=7

# %%
a+b
# Out:
# 50

# %%
a/b
# Out:
# 6.142857142857143

# %%
a*b
# Out:
# 301

# %%
a-b
# Out:
# 36

# %%
2**2
# Out:
# 4

# %%
b**2
# Out:
# 49

# %%
a%b
# Out:
# 1

# %%
a=34

# %%
b=45

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
c=34

# %%
a==c  #ais equal to c
# Out:
# True

# %%
a<=c
# Out:
# True

# %%
a>=c
# Out:
# True

# %%
b1=True
b2=False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a=5
b=3
a & b
# Out:
# 1

# %%
a|b
# Out:
# 7

# %%
a=40

# %%
a-=4

# %%
a
# Out:
# 36

# %%
a+=4

# %%
a
# Out:
# 40

# %%
a//=5
a
# Out:
# 1

# %%
11//2
# Out:
# 5

# %%
a//=2

# %%
a=30
a//=2
a
# Out:
# 15

# %%
L=[1,2,3,4,5,6]
D=[1,3,4,5,6]
# x=2
2 in L
D is L
# Out:
# False
