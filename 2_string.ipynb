# %%
name="Abhinandan"
name
# Out:
# 'Abhinandan'

# %%
name.upper()
# Out:
# 'ABHINANDAN'

# %%
name.endswith("an")
# Out:
# True

# %%
name.lower()
# Out:
# 'abhinandan'

# %%
name.count("n")
# Out:
# 3

# %%
len(name)
# Out:
# 10

# %%
word="Banana,apple"
word.split(',')
# Out:
# ['Banana', 'apple']

# %%
word=['Banana', 'apple']
" ".join(word)
# Out:
# 'Banana apple'

# %%
name[0:4]
# Out:
# 'Abhi'

# %%
name[:-6]
# Out:
# 'Abhi'
