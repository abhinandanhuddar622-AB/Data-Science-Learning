# %%
result=10+6*3

# %%
result
# Out:
# 28

# %%
result=2**3**2   # right To left  <----
result
# Out:
# 512

# %%
n=3**2
n
# Out:
# 9

# %%
m=2**9
m
# Out:
# 512

# %%
v=16/4*2  #left To right  ----->
v
# Out:
# 8.0

# %%
a=3+4/2*4+8-2

# %%
a
# Out:
# 17.0

# %%
#  ** is evaluated right to left
#  *,/,// and % is evaluated left to right
