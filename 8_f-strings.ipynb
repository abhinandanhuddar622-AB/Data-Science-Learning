# %%
# string formatting
name="Abhinandan"
skills="python, sql ,Data science."

print("My name is {}, and i have skill in {}".format(name,skills))
# Out:
# My name is Abhinandan and i have skill in python, sql ,Data science.

# %%
print(f"My name is {name}, and i have skill in {skills}")
# Out:
# My name is Abhinandan, and i have skill in python, sql ,Data science.

# %%
print(f"{"Abhi":<10}")  #left-align and width 10 character
print(f"{"Abhi":>10}")  #Right-align
print(f"{"Abhi":^10}")  #Center-align
# Out:
# Abhi
#       Abhi
#    Abhi
