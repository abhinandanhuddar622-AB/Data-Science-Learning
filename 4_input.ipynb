# %%
a=input("Enter the value of a")
#by default it takes the user input as a string
# Out:
# Enter the value of a 4

# %%
a
# Out:
# '4'

# %%
b=input("Enter the value of a")
# Out:
# Enter the value of a 4

# %%
a+b
# Out:
# '44'

# %%
int(a)+int(b)
# Out:
# 8
