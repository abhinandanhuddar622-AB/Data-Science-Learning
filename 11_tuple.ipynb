# %%
e=()
type(e)
# Out:
# tuple

# %%
t=(34,5,45,5,2)
len(t)
# Out:
# 5

# %%
t.index(45)   # find index of 45
# Out:
# 2

# %%
t.count(5)  #count 5 in t
# Out:
# 2

# %%
len(t)  # length
# Out:
# 5

# %%
t[1]  # find value
# Out:
# 5

# %%
t[1]=6  #does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 t[1]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
word=("Abhi",22,"Engineer")

# %%
name,age,profession=word  #as

# %%
name
# Out:
# 'Abhi'

# %%
age
# Out:
# 22

# %%
profession
# Out:
# 'Engineer'
