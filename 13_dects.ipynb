# %%
d={}
type(d)
# Out:
# dict

# %%
student={'name':"Abhi","age":22}
student
# Out:
# {'name': 'Abhi', 'age': 22}

# %%
student["name"]
# Out:
# 'Abhi'

# %%
r=student.get("name3")
print(r)
# Out:
# None

# %%
student["age"]=23
student
# Out:
# {'name': 'Abhi', 'age': 23}

# %%
student.items()
# Out:
# dict_items([('name', 'Abhi'), ('age', 23)])

# %%
student.values()
# Out:
# dict_values(['Abhi', 23])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.update({"name":"Abhinandan","lang":"python"})
student
# Out:
# {'name': 'Abhinandan', 'age': 23, 'lang': 'python'}

# %%
student.setdefault("city","ben")
# Out:
# 'ben'
