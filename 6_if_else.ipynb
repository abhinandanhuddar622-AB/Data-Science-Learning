# %%
a=20
if(a>6):
   print("Greater") 
else:
    print("smaller")
# Out:
# Greater

# %%
a=int(input("Enter your percentege"))
if(a>=90):
    print("Grade A")
elif(a>=70):
    print("Grade B")
elif(a>=50):
    print("Grade C")
elif(a<50):
    print("Grade D")
# Out:
# Enter your percentege 50
# Grade C

# %%
import pandas as pd
data={'name':['abhi','sam','ram'],'score':[90,85,60]}
df=pd.DataFrame(data)
df['Result']=df['score'].apply(lambda x: 'Pass' if x>=50 else 'Fail')
print(df)
# Out:
#    name  score Result
# 0  abhi     90   Pass
# 1   sam     85   Pass
# 2   ram     60   Pass

# %%
def avg(a,b):
    return (a+b)/2
avg(4,6)
# Out:
# 5.0

# %%
def avg(a,b,c=8):   # also set default argument
    return (a+b+c)/2
avg(4,6)
# Out:
# 9.0

# %%
def greet():
    print("Hello good Morning")
greet()
# Out:
# Hello good Morning
