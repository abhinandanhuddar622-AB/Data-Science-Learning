# %%
a=5

# %%
b=46

# %%
a+b
# Out:
# 51

# %%
name="Abhi"

# %%
print(name)
# Out:
# Abhi

# %%
# hey i  am learning python
'''
hey i am Learning python
'''

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)  # no need to print
# Out:
# str

# %%
a="1008"

# %%
b="1008"

# %%
print(a+b)
# Out:
# 10081008

# %%
int(a)+int(b)   #Typecasting
# Out:
# 2016

# %%
z = int(5.9)
type(z)
# Out:
# int
