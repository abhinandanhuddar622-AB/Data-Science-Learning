# %%
a={}
type(a)
# Out:
# dict

# %%
a=()
type(a)
# Out:
# tuple

# %%
s=set()
type(s)
# Out:
# set

# %%
s1={1,2,3,4,4}
s
# Out:
# {1, 2, 3, 4}

# %%
type(s1)
# Out:
# set

# %%
s2=set([1,2,3,4,4,5])  # Sets do not allow duplicate elements
type(s2)
# Out:
# set

# %%
s2
# Out:
# [1, 2, 3, 4, 4, 5]

# %%
s2.update([6,7,3])
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s2.add(8)
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s2.remove(8)
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s2.discard(7)   # does not raiise an error if not found
s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s2.pop()   #removes and returns a random element
s2
# Out:
# {2, 3, 4, 5, 6}

# %%
s3={1,2,3,4,4,4}
s3.clear()
s3
# Out:
# set()

# %%
s4={1,2,3,4,4,4}
e=s4.copy()
s4.remove(4)
e
# Out:
# {1, 2, 3, 4}

# %%
s4
# Out:
# {1, 2, 3}

# %%
set1={1,2,3,4,4,4}
set2={1,2,3,4,4,4,5,8,0}

# %%
set1.union(set2)
# Out:
# {0, 1, 2, 3, 4, 5, 8}

# %%
set1.intersection(set2)
# Out:
# {1, 2, 3, 4}

# %%
set1.issubset(set2)
# Out:
# True

# %%
set2.issuperset(set1)
# Out:
# True
